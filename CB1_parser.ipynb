# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from decimal import Decimal, ROUND_HALF_UP

# %% [markdown]
# ***1) Ki section***

# %%
# Dataset importing
imported_db_Ki = pd.read_csv(r'/filepath1/file.csv', sep=';')

# %%
# Certain columns selection
list_of_columns = ['Molecule ChEMBL ID','Smiles','Standard Type', 'Standard Relation', 'Standard Value',
'Standard Units','Document ChEMBL ID', 'Target Name', 'Action Type']
df_Ki = pd.DataFrame(data=imported_db_Ki,
                  columns=list_of_columns)


df_Ki.rename(columns={'Molecule ChEMBL ID':'Molecule_ChEMBL_ID',
                   'Standard Type':'Standard_Type',
                   'Standard Relation':'Standard_Relation',
                   'Standard Value':'Standard_Value',
                   'Standard Units':'Standard_Units',
                   'Document ChEMBL ID':'Document_ChEMBL_ID',
                   'Action Type':'Action_Type',
                   'Target Name':'Target_Name'}, inplace=True)

# %%
# Deleting NaN values
df_dropped_Ki = df_Ki.dropna()

# %%
# Filtering 'df_dropped_Ki' dataframe for records equal to 'ANTAGONIST' or 'BLOCKER' in 'Action_Type' column
# Filtering 'df_dropped_Ki' dataframe for records equal with activity equal or less than 50
df_dropped_Ki = df_dropped_Ki[df_dropped_Ki['Action_Type'].isin(['ANTAGONIST', 'BLOCKER'])]
df_dropped_Ki = df_dropped_Ki[df_dropped_Ki['Standard_Value'] <= 50]

# %% [markdown]
# ***2) IC50 section***

# %%
# Dataset importing
imported_db_IC50 = pd.read_csv(r'/filepath1/file.csv', sep=';')

# %%
# Certain columns selection
list_of_columns = ['Molecule ChEMBL ID','Smiles','Standard Type', 'Standard Relation', 'Standard Value',
'Standard Units','Document ChEMBL ID', 'Target Name', 'Action Type']
df_IC50 = pd.DataFrame(data=imported_db_IC50,
                  columns=list_of_columns)


df_IC50.rename(columns={'Molecule ChEMBL ID':'Molecule_ChEMBL_ID',
                   'Standard Type':'Standard_Type',
                   'Standard Relation':'Standard_Relation',
                   'Standard Value':'Standard_Value',
                   'Standard Units':'Standard_Units',
                   'Document ChEMBL ID':'Document_ChEMBL_ID',
                   'Action Type':'Action_Type',
                   'Target Name':'Target_Name'}, inplace=True)

# %%
# Deleting NaN values
df_dropped_IC50 = df_IC50.dropna()

# %%
# Filtering 'df_dropped_Ki' dataframe for records equal to 'ANTAGONIST' or 'BLOCKER' in 'Action_Type' column
# Filtering 'df_dropped_Ki' dataframe for records equal with activity equal or less than 50
df_dropped_IC50 = df_dropped_IC50[df_dropped_IC50['Action_Type'].isin(['ANTAGONIST', 'BLOCKER'])]
df_dropped_IC50 = df_dropped_IC50[df_dropped_IC50['Standard_Value'] <= 50]

# %%
# Ki- IC50 conversion factor of 2 propsed by Kalliokoski et al. in "Comparability of Mixed IC50 Data – A Statistical Analysis"
df_dropped_IC50.Standard_Type = 'Ki'
df_dropped_IC50.Standard_Value = df_dropped_IC50.Standard_Value/2

# %% [markdown]
# **3) Łączenie dataframe'ów**

# %%
# Concatenating dataframes
output_df = pd.concat([df_dropped_IC50, df_dropped_Ki])

# %%
# Calculating the arithmetic mean of 'Standard_Values' for duplicate records (defined by 'Molecule_ChEMBL_ID' column) and subsequent removal of duplicated records
features = [col for col in output_df.columns if col not in ['Standard_Value', 'Molecule_ChEMBL_ID']]

agg_dict = {'Standard_Value': 'mean'}
agg_dict.update({feature: 'first' for feature in features})

optimized_output_df = output_df.groupby('Molecule_ChEMBL_ID').agg(agg_dict).reset_index()

# %%
# Values rounding
optimized_output_df['Standard_Value'] = optimized_output_df['Standard_Value'].apply(
    lambda x: Decimal(str(x)).quantize(Decimal('0.001'), rounding=ROUND_HALF_UP))

# %%
# Reindexing dataframe's columns
optimized_output_df = optimized_output_df.reindex(columns=['Molecule_ChEMBL_ID', 'Smiles', 'Standard_Type',
       'Standard_Relation', 'Standard_Value', 'Standard_Units',
       'Document_ChEMBL_ID', 'Target_Name', 'Action_Type'])
optimized_output_df
# Out:
#    Molecule_ChEMBL_ID                                             Smiles  \
# 0           CHEMBL111  Cc1c(C(=O)NN2CCCCC2)nn(-c2ccc(Cl)cc2Cl)c1-c1cc...
# 1        CHEMBL334533  CCCCCCC(C)(C)c1cc(O)c2c(c1)OC(C)(C)[C@H]1CC=C(...
# 2       CHEMBL4781965  COc1ccc(-c2cc(C(=O)NC3CCCCCC3)c(=O)n(Cc3ccc(F)...
# 3       CHEMBL4856192     CCCCCn1cc(C(=O)c2ccc3c(c2)CC(C)(C)C3)c2ccccc21
# 4       CHEMBL4860950       CCCCCn1cc(C(=O)c2cccc3c2CC(C)(C)C3)c2ccccc21
# 5       CHEMBL5070349  CS/C(N)=N/C(=N/S(=O)(=O)N1CCC(C(F)(F)F)CC1)N1C...
# 6       CHEMBL5071344  N/C(=N\C(=N\S(=O)(=O)N1CCC(C(F)(F)F)CC1)N1CC(c...
# 7       CHEMBL5073465  C/C(N)=N/C(=N/S(=O)(=O)N1CCC(C(F)(F)F)CC1)N1CC...
# 8       CHEMBL5075684  CCN(CC)S(=O)(=O)/N=C(/N=C(\N)c1ccc(F)cc1)N1CC(...
# 9       CHEMBL5076422  CS/C(N)=N\C(=N\S(=O)(=O)N1CCC(F)(F)CC1)N1CC(c2...
# 10      CHEMBL5076792  CC(C)(C)/C(N)=N/C(=N/S(=O)(=O)N1CCC(C(F)(F)F)C...
# 11      CHEMBL5078566  CC(C)(C)/C(N)=N/C(=N/S(=O)(=O)N1CCC(F)(F)CC1)N...
# 12      CHEMBL5080268  CS/C(N)=N/C(=N/S(=O)(=O)N1CCC(C(F)(F)F)CC1)N1C...
# 13      CHEMBL5080386  C/C(N)=N/C(=N/S(=O)(=O)N1CCOCC1)N1CC(c2ccccc2)...
# 14      CHEMBL5081180  CCN(CC)S(=O)(=O)/N=C(/N=C(\N)SC)N1CC(c2ccccc2)...
# 15      CHEMBL5081757  C/C(N)=N/C(=N/S(=O)(=O)N1CCCC1)N1CC(c2ccccc2)C...
# 16      CHEMBL5083073  N/C(=N\C(=N\S(=O)(=O)N1CCC(F)(F)CC1)N1CC(c2ccc...
# 17      CHEMBL5083217  N/C(=N\C(=N\S(=O)(=O)N1CCOCC1)N1CC(c2ccccc2)C(...
# 18      CHEMBL5084492  N/C(=N/C(=N/S(=O)(=O)N1CCCCC1)N1CC(c2ccccc2)C(...
# 19      CHEMBL5084505  CS/C(N)=N/C(=N/S(=O)(=O)N1CCOCC1)N1CC(c2ccccc2...
# 20      CHEMBL5084642  N/C(=N\C(=N\S(=O)(=O)N1CCCC1)N1CC(c2ccccc2)C(c...
# 21      CHEMBL5085017  CCN(CC)S(=O)(=O)/N=C(/N=C(/C)N)N1C[C@H](c2cccc...
# 22      CHEMBL5085413  CCN(CC)S(=O)(=O)/N=C(/N=C(\N)C(C)(C)C)N1CC(c2c...
# 23      CHEMBL5086256  N/C(=N\C(=N\S(=O)(=O)N1CCOCC1)N1CC(c2ccccc2)C(...
# 24      CHEMBL5086960  CCN(CC)S(=O)(=O)/N=C(/N=C(\N)c1ccc(Cl)cc1)N1CC...
# 25      CHEMBL5087041  C/C(N)=N\C(=N\S(=O)(=O)N1CCC(F)(F)CC1)N1CC(c2c...
# 26      CHEMBL5087110  C/C(N)=N\C(=N\S(=O)(=O)N1CCCCC1)N1CC(c2ccccc2)...
# 27      CHEMBL5087159  CS/C(N)=N/C(=N/S(=O)(=O)N1CCCC1)N1CC(c2ccccc2)...
# 28      CHEMBL5087924  CS/C(N)=N\C(=N\S(=O)(=O)N1CCCCC1)N1CC(c2ccccc2...
# 29      CHEMBL5087941  CC(C)(C)/C(N)=N\C(=N\S(=O)(=O)N1CCCCC1)N1CC(c2...
# 30      CHEMBL5088275  CC(C)(C)/C(N)=N/C(=N/S(=O)(=O)N1CCOCC1)N1CC(c2...
# 31      CHEMBL5088686  N/C(=N\C(=N\S(=O)(=O)N1CCC(C(F)(F)F)CC1)N1CC(c...
# 32      CHEMBL5089095  N/C(=N/C(=N/S(=O)(=O)N1CCCCC1)N1CC(c2ccccc2)C(...
# 33      CHEMBL5090020  CCN(CC)S(=O)(=O)/N=C(/N=C(/C)N)N1CC(c2ccccc2)C...
# 34      CHEMBL5092394  N/C(=N\C(=N\S(=O)(=O)N1CCC(F)(F)CC1)N1CC(c2ccc...
# 35      CHEMBL5093228  C/C(N)=N\C(=N\S(=O)(=O)N1CCCCC1)N1C[C@H](c2ccc...
# 36      CHEMBL5266788  Cc1c(C(=O)NC23CC4CC(CC(C4)C2)C3)nn(CCCCCO)c1-c...
# 37       CHEMBL561013            CCCCCn1cc(C(=O)c2cccc3ccccc23)c2ccccc21
#
#    Standard_Type Standard_Relation Standard_Value Standard_Units  \
# 0             Ki               '='         10.800             nM
# 1             Ki               '='         19.000             nM
# 2             Ki               '='          9.800             nM
# 3             Ki               '='         38.800             nM
# 4             Ki               '='          1.460             nM
# 5             Ki               '='          0.850             nM
# 6             Ki               '='          4.100             nM
# 7             Ki               '='          3.900             nM
# 8             Ki               '='          5.500             nM
# 9             Ki               '='         14.000             nM
# 10            Ki               '='          1.050             nM
# 11            Ki               '='         13.000             nM
# 12            Ki               '='          2.100             nM
# 13            Ki               '='         31.000             nM
# 14            Ki               '='         13.000             nM
# 15            Ki               '='          7.400             nM
# 16            Ki               '='          3.800             nM
# 17            Ki               '='         24.700             nM
# 18            Ki               '='          4.200             nM
# 19            Ki               '='         41.000             nM
# 20            Ki               '='         10.500             nM
# 21            Ki               '='          0.900             nM
# 22            Ki               '='         10.000             nM
# 23            Ki               '='         15.850             nM
# 24            Ki               '='         10.800             nM
# 25            Ki               '='          5.450             nM
# 26            Ki               '='          3.000             nM
# 27            Ki               '='         23.000             nM
# 28            Ki               '='         15.000             nM
# 29            Ki               '='         23.000             nM
# 30            Ki               '='         17.000             nM
# 31            Ki               '='         10.593             nM
# 32            Ki               '='          5.400             nM
# 33            Ki               '='          3.425             nM
# 34            Ki               '='          2.750             nM
# 35            Ki               '='          1.800             nM
# 36            Ki               '='         13.000             nM
# 37            Ki               '='          9.000             nM
#
#    Document_ChEMBL_ID               Target_Name Action_Type
# 0       CHEMBL1140299  Cannabinoid CB1 receptor  ANTAGONIST
# 1       CHEMBL1140299  Cannabinoid CB1 receptor  ANTAGONIST
# 2       CHEMBL4706601  Cannabinoid CB1 receptor  ANTAGONIST
# 3       CHEMBL4825669  Cannabinoid CB1 receptor  ANTAGONIST
# 4       CHEMBL4825669  Cannabinoid CB1 receptor  ANTAGONIST
# 5       CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 6       CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 7       CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 8       CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 9       CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 10      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 11      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 12      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 13      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 14      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 15      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 16      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 17      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 18      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 19      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 20      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 21      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 22      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 23      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 24      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 25      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 26      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 27      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 28      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 29      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 30      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 31      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 32      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 33      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 34      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 35      CHEMBL5046268  Cannabinoid CB1 receptor  ANTAGONIST
# 36      CHEMBL5223099  Cannabinoid CB1 receptor  ANTAGONIST
# 37      CHEMBL4825669  Cannabinoid CB1 receptor  ANTAGONIST

# %%
# Output dataframe saving
# optimized_output_df.to_csv('/output_directory_path/Filtered_complete_output_df.csv', index=False)
